# %% [markdown]
# <a href="https://colab.research.google.com/github/lolasilvag/faculdade/blob/main/Aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic image processing using OpenCV

import cv2
import requests
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO

# Fetch the image from the URL using requests
url = 'https://images.unsplash.com/photo-1444464666168-49d633b86797?w=800&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8YmlyZHxlbnwwfHwwfHx8Mg%3D%3D'
response = requests.get(url)
image = np.asarray(bytearray(response.content), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply a Gaussian blur to the image
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

# Detect edges using the Canny edge detection algorithm
edges = cv2.Canny(blurred_image, 100, 200)

# Display the original and processed images
plt.figure(figsize=(10, 7))

plt.subplot(2, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(799.5), np.float64(533.5), np.float64(-0.5))

# %%
# Importa a biblioteca cv2
import cv2
from google.colab.patches import cv2_imshow
import requests
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO

# Busca a imagem da URL usando requests
url = 'https://images.unsplash.com/photo-1444464666168-49d633b86797?w=800&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8YmirdHxlbnwwfHwwfHx8Mg%3D%3D'
response = requests.get(url)
image = np.asarray(bytearray(response.content), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)

# Modifica os valores dos pixels da imagem
for y in range(0, image.shape[0]):  # percorre linhas
    for x in range(0, image.shape[1]):  # percorre colunas
        image[y, x] = (x % 256, y % 256, x % 256) # Use row and column indices for color components

# Exibe a imagem modificada
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x534>
# -1

# %%
# Busca a imagem da URL usando requests
url = 'https://images.unsplash.com/photo-1444464666168-49d633b86797?w=800&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8YmlyZHxlbnwwfHwwfHx8Mg%3D%3D'
response = requests.get(url)
image = np.asarray(bytearray(response.content), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)

# Modifica os valores dos pixels da imagem
for y in range(0, image.shape[0]):  # percorre linhas
    for x in range(0, image.shape[1]):  # percorre colunas
        image[y, x] = (x % 256, y % 256, x % 256)

# Exibe a imagem modificada
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x534>
# -1

# %%
# Importa as bibliotecas necessárias
from google.colab.patches import cv2_imshow

# Busca a imagem da URL usando requests
url = 'https://images.unsplash.com/photo-1444464666168-49d633b86797?w=800&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8YmlyZHxlbnwwfHwwfHx8Mg%3D%3D'
response = requests.get(url)
image = np.asarray(bytearray(response.content), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)

# Converte a imagem para escala de cinza
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Aplica um desfoque gaussiano na imagem
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

# Detecta bordas usando o algoritmo de detecção de bordas de Canny
edges = cv2.Canny(blurred_image, 100, 200)

# Modifica os valores dos pixels da imagem original
for y in range(0, image.shape[0], 1):  # percorre as linhas
    for x in range(0, image.shape[1], 1):  # percorre as colunas
        image[y, x] = (0, (x * y) % 256, 0)

# Exibe a imagem modificada
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x534>
# -1

# %%
from google.colab.patches import cv2_imshow
# Busca a imagem da URL usando requests
url = 'https://images.unsplash.com/photo-1444464666168-49d633b86797?w=800&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8YmlyZHxlbnwwfHwwfHx8Mg%3D%3D'
response = requests.get(url)
image = np.asarray(bytearray(response.content), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)

# Converte a imagem para escala de cinza
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Aplica um desfoque gaussiano na imagem
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

# Detecta bordas usando o algoritmo de detecção de bordas de Canny
edges = cv2.Canny(blurred_image, 100, 200)

for y in range(0, image.shape[0], 10):  # percorre linhas
    for x in range(0, image.shape[1], 10):  # percorre colunas
        image[y:y+5, x:x+5] = (0, 255, 255)  # Altera os pixels em uma região 5x5 para a cor amarela

# Exibe a imagem modificada
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x534>
# -1

# %%
# 1: Upload da imagem
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt

uploaded = files.upload()  # Abre janela para selecionar imagem

# 2: Abrir a imagem
for filename in uploaded.keys():
    img = Image.open(filename)

    # 3: Converter para preto e branco (tons de cinza)
    img_bw = img.convert('L')  # 'L' = modo grayscale

    # 4: Mostrar imagem original e convertida
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.title("Imagem Original")
    plt.imshow(img)
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title("Imagem Preto e Branco")
    plt.imshow(img_bw, cmap='gray')
    plt.axis('off')

    plt.tight_layout()
    plt.show()
# Out:
#      <input type="file" id="files-cbcb6d70-2b38-4616-829f-76f1ab7fcb21" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbcb6d70-2b38-4616-829f-76f1ab7fcb21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload da imagem
from google.colab import files
from PIL import Image
import numpy as np

uploaded = files.upload()

#  Abrir e converter a imagem para RGB
for filename in uploaded.keys():
    img = Image.open(filename).convert('RGB')
    img_array = np.array(img)

    #  Exibir forma (dimensões) da imagem e parte da matriz
    print(f"Tamanho da imagem: {img_array.shape}")

    # Mostrar uma parte da matriz (exemplo: primeiros 5x5 pixels)
    print("\nParte da matriz de pixels (5x5 pixels):")
    print(img_array[:5, :5, :])
# Out:
#      <input type="file" id="files-c5115c4c-356b-4187-9370-b4de2eefc8a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5115c4c-356b-4187-9370-b4de2eefc8a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
